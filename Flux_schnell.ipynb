# %% [markdown]
# <a href="https://colab.research.google.com/github/MatinLabkhandagh/flux_dev_vs_schnell/blob/main/Flux_schnell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 28.6 MB/s eta 0:00:00
# ...

# %%
import torch
from diffusers import FluxPipeline
import matplotlib.pyplot as plt
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
pipe = FluxPipeline.from_pretrained("black-forest-labs/FLUX.1-schnell", torch_dtype=torch.bfloat16)
pipe.enable_model_cpu_offload()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/536 [00:00<?, ?B/s]
# Fetching 23 files:   0%|          | 0/23 [00:00<?, ?it/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/274 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# (…)t_encoder_2/model.safetensors.index.json:   0%|          | 0.00/19.9k [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# ...

# %% [markdown]
# # **Prompts requiring extreme detail or specificity:**

# %%
prompt = "A photorealistic image of a hummingbird sipping nectar from a flower, with a raindrop clinging to its beak and sunlight sparkling in its wings."
image = pipe(
    prompt,
    height=1024,
    width=1024,
    guidance_scale=3.5,
    num_inference_steps=50,
    max_sequence_length=512,
    generator=torch.Generator("cpu").manual_seed(0)
).images[0]
image.save("flux-schnell_2.png")
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# # **Prompts with complex compositions or unusual perspectives:**

# %%
prompt = "A portrait of a person with their face reflected in a distorted mirror, creating a surreal and unsettling image."
image = pipe(
    prompt,
    height=1024,
    width=1024,
    guidance_scale=3.5,
    num_inference_steps=50,
    max_sequence_length=512,
    generator=torch.Generator("cpu").manual_seed(0)
).images[0]
image.save("flux-schnell_2.png")
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# # **Prompts that involve combining disparate elements or styles:**

# %%
prompt = "A photorealistic image of a person dressed in a traditional Japanese kimono, standing in front of a modern skyscraper."
image = pipe(
    prompt,
    height=1024,
    width=1024,
    guidance_scale=3.5,
    num_inference_steps=50,
    max_sequence_length=512,
    generator=torch.Generator("cpu").manual_seed(0)
).images[0]
image.save("flux-schnell_3.png")
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# # **Iranian Pilot and Fighter Jet**

# %%
prompt = "A photorealistic image of an Iranian pilot wearing dark aviator sunglasses, standing next to an Iranian fighter jet. The pilot should be smiling at the camera, and the background should be a clear blue sky. The fighter jet should be a modern model with advanced weaponry. The image should capture the pilot's confidence and the power of the aircraft."
image = pipe(
    prompt,
    height=1024,
    width=1024,
    guidance_scale=3.5,
    num_inference_steps=50,
    max_sequence_length=512,
    generator=torch.Generator("cpu").manual_seed(0)
).images[0]
image.save("flux-schnell_4.png")
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
